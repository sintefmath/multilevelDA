# %% [markdown]
# # Initialising ML-Ensemble in Basin

# %% [markdown]
# ### Classes and modules

# %%
#Lets have matplotlib "inline"
# %matplotlib inline

import os
import sys

#Import packages we need
import numpy as np
import datetime
from IPython.display import display
import copy

#For plotting
import matplotlib
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

plt.rcParams["lines.color"] = "w"
plt.rcParams["text.color"] = "w"
plt.rcParams["axes.labelcolor"] = "w"
plt.rcParams["xtick.color"] = "w"
plt.rcParams["ytick.color"] = "w"

plt.rcParams["image.origin"] = "lower"

import pycuda.driver as cuda

# %% [markdown]
# GPU Ocean-modules:

# %%
from gpuocean.utils import IPythonMagic, Common
from gpuocean.SWEsimulators import CDKLM16, ModelErrorKL

# %%
# %cuda_context_handler gpu_ctx

# %%
gpu_stream = cuda.Stream()

# %% [markdown]
# Utils

# %%
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '../')))
from utils.BasinInit import *

# %% [markdown]
# ### Perturbing initial conditions

# %%
sample_args = {
    "g": 9.81,
    "f": 0.0012,
    }

# %%
ls = [6, 7, 8, 9, 10]

# %%
args_list = []

for l in ls:
    lvl_grid_args = initGridSpecs(l)
    args_list.append( {
        "nx": lvl_grid_args["nx"],
        "ny": lvl_grid_args["ny"],
        "dx": lvl_grid_args["dx"],
        "dy": lvl_grid_args["dy"],
        "gpu_ctx": gpu_ctx,
        "gpu_stream": gpu_stream,
        "boundary_conditions": Common.BoundaryConditions(2,2,2,2)
        } )

# %%
init_model_error_basis_args = {
    "basis_x_start": 1, 
    "basis_x_end": 6,
    "basis_y_start": 2,
    "basis_y_end": 7,

    "kl_decay": 1.25,
    "kl_scaling": 0.05,
}

# %%
sim_model_error_basis_args = {
    "basis_x_start": 1, 
    "basis_x_end": 7,
    "basis_y_start": 2,
    "basis_y_end": 8,

    "kl_decay": 1.25,
    "kl_scaling": 0.0025,
}

# %% [markdown]
# ### Ensemble

# %%
read_path = "/home/florianb/havvarsel/multilevelDA/scripts/VarianceLevels/Basin/2023-05-11T15_47_53"

vars = np.load(read_path+"/vars_43200.npy")
diff_vars = np.load(read_path+"/diff_vars_43200.npy")

# %%
from utils.BasinAnalysis import *
analysis = Analysis(args_list, vars, diff_vars)

# %%
analysis.plotLvlVar(relative=True)

# %%
ML_Nes = analysis.optimal_Ne(tau=2e-2)
ML_Nes
# Out:
# array([7114,  808,  106,   11,    2], dtype=int32)

# %%
np.mean(vars[0])*1/(1e-2)**2
# Out:
# 131467.7839306445

# %% [markdown]
# ### Ensemble

# %%
data_args_list = []

for l_idx in range(len(ML_Nes)):
    print(l_idx)
    data_args_list.append( make_init_steady_state(args_list[l_idx]) )

# %%
from utils.BasinEnsembleInit import *

# %%
ML_ensemble = initMLensemble(ML_Nes, args_list, data_args_list, sample_args, 
                             init_model_error_basis_args=init_model_error_basis_args, 
                             sim_model_error_basis_args=sim_model_error_basis_args, sim_model_error_time_step=60.0)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 1
# 2
# 3
# 4

# %%
from gpuocean.ensembles import MultiLevelOceanEnsemble

# %%
MLOceanEnsemble = MultiLevelOceanEnsemble.MultiLevelOceanEnsemble(ML_ensemble)

# %% [markdown]
# ### Statistics

# %%
MLmean = MLOceanEnsemble.estimate(np.mean)
imshow3(MLmean, eta_vlim=1, huv_vlim=25)
# Out:
# (<Figure size 1080x720 with 6 Axes>,
#  array([<AxesSubplot:title={'center':'$\\eta$'}>,
#         <AxesSubplot:title={'center':'$hu$'}>,
#         <AxesSubplot:title={'center':'$hv$'}>], dtype=object))

# %%
ML_state = MLOceanEnsemble.download()

# %%
fig, axs = plt.subplots(len(ls), 3, figsize=(10,20))

fig.suptitle("Means per level",y=0.925)

eta_vlim = 1
huv_lim = 25

axs[0,0].set_title("eta")
axs[0,1].set_title("hu")
axs[0,2].set_title("hv")

axs[0,0].set_ylabel("level "+str(0))
axs[0,2].yaxis.set_label_position("right")
axs[0,2].set_ylabel("Ne = "+str(ML_Nes[0]), labelpad = 50)

etahuhv = np.mean(ML_state[0],axis=-1)
im = axs[0,0].imshow(etahuhv[0], vmin=-eta_vlim, vmax=eta_vlim, cmap="coolwarm")
plt.colorbar(im, ax=axs[0,0], shrink=0.5)
axs[0,0].set_title("$\eta$", fontsize=15)

im = axs[0,1].imshow(etahuhv[1], vmin=-huv_lim, vmax=huv_lim, cmap="coolwarm")
plt.colorbar(im, ax=axs[0,1], shrink=0.5)
axs[0,1].set_title("$hu$", fontsize=15)

im = axs[0,2].imshow(etahuhv[2], vmin=-huv_lim, vmax=huv_lim, cmap="coolwarm")
plt.colorbar(im, ax=axs[0,2], shrink=0.5)
axs[0,2].set_title("$hv$", fontsize=15)

for l_idx in range(1,len(ls)):
    axs[l_idx,0].set_ylabel("diff level "+str(l_idx))
    axs[l_idx,2].yaxis.set_label_position("right")
    axs[l_idx,2].set_ylabel("Ne = "+str(ML_Nes[l_idx]), labelpad = 50)

    etahuhv = np.mean(ML_state[l_idx][0],axis=-1) - np.mean(ML_state[l_idx][1],axis=-1).repeat(2,1).repeat(2,2)
    im = axs[l_idx,0].imshow(etahuhv[0], vmin=-eta_vlim/(10**(l_idx+1)), vmax=eta_vlim/(10**(l_idx+1)), cmap="coolwarm")
    plt.colorbar(im, ax=axs[l_idx,0], shrink=0.5)

    im = axs[l_idx,1].imshow(etahuhv[1], vmin=-huv_lim/(10**(l_idx+1)), vmax=huv_lim/(10**(l_idx+1)), cmap="coolwarm")
    plt.colorbar(im, ax=axs[l_idx,1], shrink=0.5)

    im = axs[l_idx,2].imshow(etahuhv[2], vmin=-huv_lim/(10**(l_idx+1)), vmax=huv_lim/(10**(l_idx+1)), cmap="coolwarm")
    plt.colorbar(im, ax=axs[l_idx,2], shrink=0.5)

# %%
MLvar = MLOceanEnsemble.estimate(np.var)
imshow3var(MLvar, eta_vlim=1e-3, huv_lim=5)
# Out:
# (<Figure size 1080x720 with 6 Axes>,
#  array([<AxesSubplot:title={'center':'$\\eta$'}>,
#         <AxesSubplot:title={'center':'$hu$'}>,
#         <AxesSubplot:title={'center':'$hv$'}>], dtype=object))

# %%
fig, axs = plt.subplots(len(ls), 3, figsize=(10,20))

fig.suptitle("Vars per level",y=0.925)

eta_vlim=1e-3
huv_lim=5

axs[0,0].set_title("eta")
axs[0,1].set_title("hu")
axs[0,2].set_title("hv")

axs[0,0].set_ylabel("level "+str(0))
axs[0,2].yaxis.set_label_position("right")
axs[0,2].set_ylabel("Ne = "+str(ML_Nes[0]), labelpad = 50)

etahuhv = np.var(ML_state[0],axis=-1)
im = axs[0,0].imshow(etahuhv[0], vmin=0.0, vmax=eta_vlim, cmap="Reds")
plt.colorbar(im, ax=axs[0,0], shrink=0.5)
axs[0,0].set_title("$\eta$", fontsize=15)

im = axs[0,1].imshow(etahuhv[1], vmin=0, vmax=huv_lim, cmap="Reds")
plt.colorbar(im, ax=axs[0,1], shrink=0.5)
axs[0,1].set_title("$hu$", fontsize=15)

im = axs[0,2].imshow(etahuhv[2], vmin=0, vmax=huv_lim, cmap="Reds")
plt.colorbar(im, ax=axs[0,2], shrink=0.5)
axs[0,2].set_title("$hv$", fontsize=15)

for l_idx in range(1,len(ls)):
    axs[l_idx,0].set_ylabel("level "+str(l_idx))
    axs[l_idx,2].yaxis.set_label_position("right")
    axs[l_idx,2].set_ylabel("Ne = "+str(ML_Nes[l_idx]), labelpad = 50)

    etahuhv = np.var(ML_state[l_idx][0],axis=-1)
    im = axs[l_idx,0].imshow(etahuhv[0], vmin=0.0, vmax=eta_vlim, cmap="Reds")
    plt.colorbar(im, ax=axs[l_idx,0], shrink=0.5)

    im = axs[l_idx,1].imshow(etahuhv[1], vmin=0, vmax=huv_lim, cmap="Reds")
    plt.colorbar(im, ax=axs[l_idx,1], shrink=0.5)

    im = axs[l_idx,2].imshow(etahuhv[2], vmin=0, vmax=huv_lim, cmap="Reds")
    plt.colorbar(im, ax=axs[l_idx,2], shrink=0.5)

# %% [markdown]
# ### Rank histograms

# %%
freq = 50
Hxs = np.arange( 512, 1024, freq)
Hys = np.arange(1024, 2048, 2*freq)

# %%
N_ranks = 100

# %%
ML_ranks = np.zeros((len(Hxs)*N_ranks,3))

# %%
sim = make_sim(args_list[-1], sample_args, init_fields=data_args_list[-1])

init_mekl = ModelErrorKL.ModelErrorKL(**args_list[-1], **init_model_error_basis_args)
init_mekl.perturbSim(sim)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2637105/3542912558.py in <module>
# ----> 1 data_args = make_init_steady_state(args_list[-1])
#       2 sim = make_sim(args_list[-1], sample_args, init_fields=data_args)
#       3
#       4 init_mekl = ModelErrorKL.ModelErrorKL(**args_list[-1], **init_model_error_basis_args)
#       5 init_mekl.perturbSim(sim)
#
# ~/havvarsel/multilevelDA/utils/BasinInit.py in make_init_steady_state(args, a, b, sample_args)
#      66
#      67     add_bump(nx*dx/2, ny*dy/2 + ny*dy/6, a, b)
# ---> 68     add_bump(nx*dx/2, ny*dy/2 - ny*dy/6, -a, b)
#      69
#      70     return {"eta": eta0, "hu": hu0, "hv": hv0, "Hi": Hi}
#
# ~/havvarsel/multilevelDA/utils/BasinInit.py in add_bump(x_bump, y_bump, a, b)
#      61         for j in range(ny):
#      62             for i in range(nx):
# ---> 63                 eta0[2+j, 2+i] += init_eta((i+0.5)*dx - x_bump, (j+0.5)*dy - y_bump, a, b)
#      64                 hu0[2+j, 2+i] +=  init_hu( (i+0.5)*dx - x_bump, (j+0.5)*dy - y_bump, a, b, H_const, sample_args["g"], sample_args["f"])
#      65                 hv0[2+j, 2+i] +=  init_hv( (i+0.5)*dx - x_bump, (j+0.5)*dy - y_bump, a, b, H_const, sample_args["g"], sample_args["f"])
#
# KeyboardInterrupt:

# %%
true_diag = np.zeros((N_ranks, 3, 1024))

# %%
for n in range(N_ranks):
    print(n)
    # new truth
    sim = make_sim(args_list[-1], sample_args, init_fields=data_args_list[-1])
    init_mekl.perturbSim(sim)

    # ranks
    ML_ranks[n*len(Hxs):(n+1)*len(Hxs)] = MLOceanEnsemble.rank(sim, [z for z in zip(Hxs, Hys)])

    # saving true diagonal
    true_diag[n] = [np.diag(v[::2,::1]) for v in sim.download(interior_domain_only=True)]

# %%
import datetime
dumptime = datetime.datetime.now().strftime("%Y-%m-%dT%H_%M_%S")
np.save("dumpRanks_"+dumptime, ML_ranks)

# %%
fig, axs = plt.subplots(1, 3, figsize=(15,3))
fig.suptitle("ML ranks",y=1.1)

axs[0].set_title("eta")
axs[1].set_title("hu")
axs[2].set_title("hv")

bins_size= 1/25
bins = np.arange(0,1+1e-9,bins_size)

for i in range(3):
    hist = np.histogram(ML_ranks[:,i], bins=bins)
    axs[i].bar(0.5*(hist[1][1:]+hist[1][:-1]),hist[0]/len(ML_ranks)/bins_size, width=bins_size, color="C0")
    
    axs[i].set_ylim((0,1.5))
    axs[i].set_xlim((0,1.0))

    axs[i].plot([0,1],[1,1], color="black", ls="--", lw=3)

# %%
fig, axs = plt.subplots(len(ls),3, figsize=(20,20))
fig.suptitle("Cut along the diagonal",  y=0.9)

# levels
for l_idx in range(len(ls)):
    axs[l_idx,0].set_ylabel("level "+str(l_idx))
    axs[l_idx,2].yaxis.set_label_position("right")
    axs[l_idx,2].set_ylabel("Ne = "+str(ML_Nes[l_idx]))

    # level state
    if l_idx == 0:
        l_state = ML_state[0]
    else:
        l_state = ML_state[l_idx][0]


    # eta hu hv
    for v in range(3):
        if v == 0:
            axs[l_idx,v].set_ylim((-1,1))
        else:
            axs[l_idx,v].set_ylim((-25,25))

        # ensemble member
        for e in range(ML_Nes[l_idx]):
            axs[l_idx,v].plot( np.diag(l_state[v,::2,::1,e]).repeat(2**(ls[-1]-ls[l_idx])), alpha=np.maximum(10/ML_Nes[l_idx],0.005), c="C0", zorder=1)

        for diag_loc in range(32,1024,64):
            loc_truthes = np.moveaxis(true_diag,0,-1)[v,diag_loc,:]
            low, mean, up = np.quantile(loc_truthes, 0.1), np.mean(loc_truthes),np.quantile(loc_truthes,0.9)
            axs[l_idx,v].scatter(diag_loc, mean, c="C1", marker="_", s=200, zorder=3)
            axs[l_idx,v].vlines(x=diag_loc, ymin=low, ymax=up, colors="C1", lw=2, zorder=2)
