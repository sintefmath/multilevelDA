# %% [markdown]
# # Rank Histograms

# %% [markdown]
# ### Classes and modules

# %%
#Lets have matplotlib "inline"
# %matplotlib inline

import os
import sys

#Import packages we need
import numpy as np
import datetime
from IPython.display import display
import copy

#For plotting
import matplotlib
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

plt.rcParams["lines.color"] = "w"
plt.rcParams["text.color"] = "w"
plt.rcParams["axes.labelcolor"] = "w"
plt.rcParams["xtick.color"] = "w"
plt.rcParams["ytick.color"] = "w"

plt.rcParams["image.origin"] = "lower"

import pycuda.driver as cuda

# %% [markdown]
# ### Ranks

# %%
source_path = "/home/florianb/havvarsel/multilevelDA/scripts/RankHistograms/BasinSL/2023-05-24T09_52_05"

# %%
def plot_histogram(T, mode, bins_size=1/25):
    # Read from file
    SL_ranks = np.load(source_path+"/SL"+mode+"Ranks_"+str(T)+".npy")
    
    fig, axs = plt.subplots(1, 3, figsize=(15,3))
    fig.suptitle(r"$\bf{SL ranks}$ for "+mode+" at "+str(T),y=1.1)

    axs[0].set_title("eta")
    axs[1].set_title("hu")
    axs[2].set_title("hv")

    bins = np.arange(0,1+1e-9,bins_size)

    for i in range(3):
        hist = np.histogram(SL_ranks[:,i], bins=bins)
        axs[i].bar(0.5*(hist[1][1:]+hist[1][:-1]),hist[0]/len(SL_ranks)/bins_size, width=bins_size, color="C0")
        
        axs[i].set_ylim((0,1.5))
        axs[i].set_xlim((0,1.0))

        axs[i].plot([0,1],[1,1], color="black", ls="--", lw=3)

# %%
plot_histogram(0, "prior")

# %%
plot_histogram(0, "posterior")

# %%
plot_histogram(900, "prior")

# %%
plot_histogram(900, "posterior")

# %%
plot_histogram(1800, "prior")

# %%
plot_histogram(1800, "posterior")

# %%
plot_histogram(3600, "prior")

# %%
plot_histogram(3600, "posterior")

# %%
plot_histogram(7200, "prior")

# %%
plot_histogram(7200, "posterior")

# %%
plot_histogram(10800, "prior")

# %%
plot_histogram(10800, "posterior")
